# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np

# %%
model_df = pd.read_csv("../data/new_model.csv")
model_df
# Out:
#        AIRPORT_ID  YEAR  MONTH  DAY_OF_MONTH    FL_DATE OP_UNIQUE_CARRIER  \
# 0             123  2018      1            22  1/22/2018                B6
# 1             150  2018      1            22  1/22/2018                EV
# 2             175  2018      1            22  1/22/2018                EV
# 3             249  2018      1            22  1/22/2018                NK
# 4             272  2018      1            22  1/22/2018                NK
# ...           ...   ...    ...           ...        ...               ...
# 15829       67509  2018     12             1  12/1/2018                OO
# 15830       67510  2018     12             1  12/1/2018                OO
# 15831       67511  2018     12             1  12/1/2018                OO
# 15832       67512  2018     12             1  12/1/2018                OO
# 15833       67689  2018     12             1  12/1/2018                AA
#
#        OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ...  \
# 0                      20409         B6   N236JB                312  ...
# 1                      20366         EV   N14158               3966  ...
# 2                      20366         EV   N12540               4014  ...
# 3                      20416         NK   N665NK                121  ...
# 4                      20416         NK   N602NK                295  ...
# ...                      ...        ...      ...                ...  ...
# 15829                  20304         OO   N724SK               3019  ...
# 15830                  20304         OO   N758SK               3053  ...
# 15831                  20304         OO   N715SK               3083  ...
# 15832                  20304         OO   N709SK               3084  ...
# 15833                  19805         AA   N176UW               1668  ...
#
#        NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY FIRST_DEP_TIME  \
# 0           12.0             0.0                 19.0            NaN
# 1           15.0             0.0                 13.0            NaN
# 2            0.0             0.0                  0.0            NaN
# 3           43.0             0.0                  0.0            NaN
# 4            0.0             0.0                168.0            NaN
# ...          ...             ...                  ...            ...
# 15829        NaN             NaN                  NaN            NaN
# 15830        NaN             NaN                  NaN            NaN
# 15831        NaN             NaN                  NaN            NaN
# 15832        NaN             NaN                  NaN            NaN
# 15833        NaN             NaN                  NaN            NaN
#
#       TOTAL_ADD_GTIME LONGEST_ADD_GTIME  field1  FL_DATE.1  \
# 0                 NaN               NaN       0  1/22/2018
# 1                 NaN               NaN       0  1/22/2018
# 2                 NaN               NaN       0  1/22/2018
# 3                 NaN               NaN       0  1/22/2018
# 4                 NaN               NaN       0  1/22/2018
# ...               ...               ...     ...        ...
# 15829             NaN               NaN      46  12/1/2018
# 15830             NaN               NaN      46  12/1/2018
# 15831             NaN               NaN      46  12/1/2018
# 15832             NaN               NaN      46  12/1/2018
# 15833             NaN               NaN      46  12/1/2018
#
#                  DurationofEvent  DurationinMinutes
# 0      0 days 00:32:00.000000000                 32
# 1      0 days 00:32:00.000000000                 32
# 2      0 days 00:32:00.000000000                 32
# 3      0 days 00:32:00.000000000                 32
# 4      0 days 00:32:00.000000000                 32
# ...                          ...                ...
# 15829  0 days 00:00:00.000000000                  0
# 15830  0 days 00:00:00.000000000                  0
# 15831  0 days 00:00:00.000000000                  0
# 15832  0 days 00:00:00.000000000                  0
# 15833  0 days 00:00:00.000000000                  0
#
# [15834 rows x 49 columns]

# %%
model_df["DurationinMinutes"].unique()
# Out:
# array([  32,   18,  113, 1302,  719,   64,  531,  893,    0,  252,  120,
#         197,  693,   72,   27,  331,   77,  137,   66,   14,  946,   90,
#           8,   41,   89,   45,  157,  195,  653,  159,   57,  819,  939,
#          15,   22,  458,    9,   24,  104,  635], dtype=int64)

# %%
duration_df = model_df[["FL_DATE", "WEATHER_DELAY", "DurationinMinutes"]]
duration_df.head(40)
# Out:
#       FL_DATE  WEATHER_DELAY  DurationinMinutes
# 0   1/22/2018            0.0                 32
# 1   1/22/2018            0.0                 32
# 2   1/22/2018            0.0                 32
# 3   1/22/2018            0.0                 32
# 4   1/22/2018            0.0                 32
# 5   1/22/2018            0.0                 32
# 6   1/22/2018            0.0                 32
# 7   1/22/2018            0.0                 32
# 8   1/22/2018            0.0                 32
# 9   1/22/2018            0.0                 32
# 10  1/22/2018            0.0                 32
# 11  1/22/2018            9.0                 32
# 12  1/22/2018           19.0                 32
# 13  1/22/2018            5.0                 32
# 14  1/22/2018            0.0                 32
# 15  1/22/2018            0.0                 32
# 16  1/22/2018            0.0                 32
# 17  1/22/2018            0.0                 32
# 18  1/22/2018            0.0                 32
# 19  1/22/2018            0.0                 32
# 20  1/22/2018           56.0                 32
# 21  1/22/2018            0.0                 32
# 22  1/22/2018            0.0                 32
# 23  1/22/2018            0.0                 32
# 24  1/22/2018            0.0                 32
# 25  1/22/2018            0.0                 32
# 26  1/22/2018           25.0                 32
# 27  1/22/2018            0.0                 32
# 28  1/22/2018            0.0                 32
# 29  1/22/2018            0.0                 32
# 30  1/22/2018            2.0                 32
# 31  1/22/2018            0.0                 32
# 32  1/22/2018            0.0                 32
# 33  1/22/2018           10.0                 32
# 34  1/22/2018           17.0                 32
# 35  1/22/2018            0.0                 32
# 36  1/22/2018            6.0                 32
# 37  1/22/2018            0.0                 32
# 38  1/22/2018           19.0                 32
# 39  1/22/2018           41.0                 32

# %%
duration_df.dropna(inplace=True)

# %%
duration_df.rename(columns={"DurationinMinutes": "LENGTH_OF_THUNDERSTORM"},inplace=True)

# %%
# duration_df["NEW_WEATHER"] = duration_df["WEATHER_DELAY"].apply(lambda x: 1 if x > 0 else 0)
# duration_df

# %%
# duration_df["NEW_THUNDERSTORM"] = duration_df["LENGTH_OF_THUNDERSTORM"].apply(lambda x: 0 if x == 0 else 1)
# duration_df

# %%
duration_df["WEATHER_DELAY"].dtype
# Out:
# dtype('float64')

# %%
duration_df["LENGTH_OF_THUNDERSTORM"].astype(float)
# Out:
# 0        32.0
# 1        32.0
# 2        32.0
# 3        32.0
# 4        32.0
#          ...
# 15746     0.0
# 15753     0.0
# 15785     0.0
# 15788     0.0
# 15814     0.0
# Name: LENGTH_OF_THUNDERSTORM, Length: 615, dtype: float64

# %%
duration_df["LENGTH_OF_THUNDERSTORM"] = duration_df["LENGTH_OF_THUNDERSTORM"].astype(float)

# %%
bins = [0.0,60.0,120.0,180.0,240.0,300.0,360.0,420.0,480.0,540.0,600.0,660.0,720.0,780.0,840.0,900.0,960.0,1020.0,1080.0,1140.0,1200.0,1260.0,1320.0] 
labels = ["0-60", "61-120", "121-180", "181-240", "241-300", "301-360", "361-420", "421-480", "481-540", "541-600", "601-660",
         "661-720", "721-780", "781-840", "841-900", "901-960", "961-1020", "1021-1080", "1081-1140", "1141-1200", "1201-1260", "1261-1320"]

# %%
duration_df["THUNDERSTORM_BINS"] = pd.cut(duration_df["LENGTH_OF_THUNDERSTORM"], bins, labels=labels, include_lowest=True)
duration_df
# Out:
#          FL_DATE  WEATHER_DELAY  LENGTH_OF_THUNDERSTORM THUNDERSTORM_BINS
# 0      1/22/2018            0.0                    32.0              0-60
# 1      1/22/2018            0.0                    32.0              0-60
# 2      1/22/2018            0.0                    32.0              0-60
# 3      1/22/2018            0.0                    32.0              0-60
# 4      1/22/2018            0.0                    32.0              0-60
# ...          ...            ...                     ...               ...
# 15746  12/1/2018         1938.0                     0.0              0-60
# 15753  12/1/2018         1707.0                     0.0              0-60
# 15785  12/1/2018         2230.0                     0.0              0-60
# 15788  12/1/2018         1309.0                     0.0              0-60
# 15814  12/1/2018          851.0                     0.0              0-60
#
# [615 rows x 4 columns]

# %%
group_df = duration_df.groupby("THUNDERSTORM_BINS").mean()
group_df
# Out:
#                    WEATHER_DELAY  LENGTH_OF_THUNDERSTORM
# THUNDERSTORM_BINS
# 0-60                  607.774194               23.568915
# 61-120               1476.625000               90.305556
# 121-180              1471.250000              158.500000
# 181-240              1343.100000              195.600000
# 241-300              1353.538462              252.000000
# 301-360              1236.375000              331.000000
# 361-420                      NaN                     NaN
# 421-480              1457.666667              458.000000
# 481-540              1464.000000              531.000000
# 541-600                      NaN                     NaN
# 601-660              1512.650000              649.400000
# 661-720              1633.363636              707.181818
# 721-780                      NaN                     NaN
# 781-840              1808.076923              819.000000
# 841-900              1678.833333              893.000000
# 901-960              1274.576923              943.307692
# 961-1020                     NaN                     NaN
# 1021-1080                    NaN                     NaN
# 1081-1140                    NaN                     NaN
# 1141-1200                    NaN                     NaN
# 1201-1260                    NaN                     NaN
# 1261-1320            1745.333333             1302.000000

# %%
group_df.fillna(0)
# Out:
#                    WEATHER_DELAY  LENGTH_OF_THUNDERSTORM
# THUNDERSTORM_BINS
# 0-60                  607.774194               23.568915
# 61-120               1476.625000               90.305556
# 121-180              1471.250000              158.500000
# 181-240              1343.100000              195.600000
# 241-300              1353.538462              252.000000
# 301-360              1236.375000              331.000000
# 361-420                 0.000000                0.000000
# 421-480              1457.666667              458.000000
# 481-540              1464.000000              531.000000
# 541-600                 0.000000                0.000000
# 601-660              1512.650000              649.400000
# 661-720              1633.363636              707.181818
# 721-780                 0.000000                0.000000
# 781-840              1808.076923              819.000000
# 841-900              1678.833333              893.000000
# 901-960              1274.576923              943.307692
# 961-1020                0.000000                0.000000
# 1021-1080               0.000000                0.000000
# 1081-1140               0.000000                0.000000
# 1141-1200               0.000000                0.000000
# 1201-1260               0.000000                0.000000
# 1261-1320            1745.333333             1302.000000

# %%
group_df.to_csv("../data/delays.csv")

# %%
group_df.to_json("../data/delays.json")

# %%
# X = clean_model.drop("NEW_WEATHER", axis=1)
# y = clean_model["NEW_THUNDERSTORM"]
# print(X.shape, y.shape)

# %%
# from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
